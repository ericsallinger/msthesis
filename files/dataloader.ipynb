# %%
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import pickle

# %%
with open('../files/phys_data.pkl', 'rb') as f:
    whole_df = pickle.load(f)

# %%
whole_df
# Out:
#      subj label                                                 hr  \
# 0       1     0  [81.0, 82.0, 83.0, 81.0, 80.0, 78.0, 77.0, 78....
# 1       1     0  [70.0, 69.0, 69.0, 70.0, 71.0, 72.0, 73.0, 73....
# 2       1     0  [64.0, 64.0, 63.0, 63.0, 63.0, 63.0, 63.0, 64....
# 3       1     0  [77.0, 78.0, 78.0, 78.0, 78.0, 76.0, 72.0, 69....
# 4       1     0  [76.0, 76.0, 76.0, 76.0, 78.0, 79.0, 79.0, 80....
# ..    ...   ...                                                ...
# 923    29     3  [149.0, 149.0, 149.0, 149.0, 149.0, 149.0, 150...
# 924    29     3  [138.0, 138.0, 139.0, 140.0, 140.0, 140.0, 140...
# 925    29     3  [138.0, 138.0, 138.0, 138.0, 139.0, 139.0, 139...
# 926    29     3  [140.0, 140.0, 141.0, 141.0, 141.0, 142.0, 142...
# 927    29     3  [139.0, 139.0, 140.0, 140.0, 141.0, 142.0, 143...
#
#                                                    hbo  \
# 0    [-0.8554872369111797, -0.57496029561218, -0.49...
# 1    [-3.9035742869604984, -3.6690829794927207, -3....
# 2    [1.3921675744672737, 1.1353524592800208, 0.991...
# 3    [7.245555498720603, 7.329383052879299, 7.18260...
# 4    [-0.6213875555732835, -0.5119793317549247, -0....
# ..                                                 ...
# 923  [-23.10538728883509, -23.05403200438451, -23.1...
# 924  [3.058798375795244, 2.655746357782251, 2.55250...
# 925  [-2.7496252732924376, -2.6766007643420946, -2....
# 926  [17.369855603108817, 17.267840840287466, 17.67...
# 927  [-0.625898442808352, -0.6398860900049662, -0.3...
#
#                                                    eda  \
# 0    [0.2815550556451113, 0.28822303060880383, 0.29...
# 1    [0.44406848525288256, 0.44719377405633287, 0.4...
# 2    [0.3726680935510207, 0.3753903461879757, 0.375...
# 3    [0.3778913025642409, 0.3804111139699416, 0.381...
# 4    [0.38933916610036545, 0.3953971906270052, 0.39...
# ..                                                 ...
# 923  [6.123965544413717, 6.09872522717756, 6.066599...
# 924  [20.37602942760572, 20.297138745295264, 20.182...
# 925  [10.658320792222952, 10.677367210273614, 10.69...
# 926  [12.171594831168214, 12.151301662457728, 12.13...
# 927  [13.675999616916716, 13.81861341589344, 13.988...
#
#                                                    hrv  \
# 0                            [nan, nan, nan, nan, nan]
# 1                            [nan, nan, nan, nan, nan]
# 2                            [nan, nan, nan, nan, nan]
# 3                            [nan, nan, nan, nan, nan]
# 4                            [nan, nan, nan, nan, nan]
# ..                                                 ...
# 923  [391.0, 392.0, 391.0, 389.0, 390.0, 388.0, 389...
# 924  [425.0, 423.0, 421.0, 420.0, 421.0, 423.0, 420...
# 925  [415.0, 416.0, 417.0, 413.0, 414.0, 416.0, 416...
# 926  [419.0, 416.0, 417.0, 418.0, 419.0, 417.0, 416...
# 927  [406.0, 405.0, 403.0, 406.0, 404.0, 405.0, 403...
#
#                                                   temp
# 0    [30.51, 30.51, 30.53, 30.53, 30.53, 30.53, 30....
# 1    [31.55, 31.55, 31.55, 31.51, 31.51, 31.51, 31....
# 2    [31.51, 31.51, 31.51, 31.49, 31.49, 31.49, 31....
# 3    [31.51, 31.51, 31.51, 31.49, 31.49, 31.49, 31....
# 4    [31.07, 31.07, 31.07, 31.07, 31.07, 31.07, 31....
# ..                                                 ...
# 923  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 924  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 925  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 926  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 927  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
#
# [928 rows x 7 columns]

# %%
input_signal = whole_df.iloc[0][['hr', 'hbo', 'eda', 'hrv', 'temp']]
input_signal
# Out:
# hr      [81.0, 82.0, 83.0, 81.0, 80.0, 78.0, 77.0, 78....
# hbo     [-0.8554872369111797, -0.57496029561218, -0.49...
# eda     [0.2815550556451113, 0.28822303060880383, 0.29...
# hrv                             [nan, nan, nan, nan, nan]
# temp    [30.51, 30.51, 30.53, 30.53, 30.53, 30.53, 30....
# Name: 0, dtype: object

# %%
signal_df = whole_df[['hr', 'hbo', 'eda', 'hrv', 'temp']]
signal_df.shape
# Out:
# (928, 5)

# %%
def find_long_nan_sequences(arr):
    nan_mask = np.isnan(arr) 

    # exception
    if np.all(nan_mask):
        return 1.0

    
    max_seq = 0
    i = 0
    
    for is_nan in nan_mask:
        if is_nan:
            # increase subsequence counter for each consecutive nan value
            i = i+1
        else:
            # if sequence is broken, save seq length and reset counter
            # this way, nan sequences all the way to the end are not included in the count 
            max_seq = max(i, max_seq)
            i = 0

    return max_seq / len(arr)

# %%
input_signal[0]
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_7644\1483495618.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   input_signal[0]
# array([81., 82., 83., 81., 80., 78., 77., 78., 78., 80., 80., 80., 80.,
#        81., 81., 82., 82., 81., 79., 77., 75., 74., 73., 73., 72., 72.,
#        72., 72., 72., 72., 71., 71., 70., 70., 70., 70., 70., 70., 69.,
#        69., 68., 68., 68., 68., 68., 68., 68., 68., 67., 67., 67., 67.,
#        68., 68., 68., 68., 68., 68., 68., 68., 68., 68., 68., 68., 68.,
#        69., 69., 69., 69., 69., 69., 69., 69., 69., 69., 69., 69., 69.,
#        69., 69., 70., 70., 70., 70., 69., 69., 68., 68., 68., 68., 68.,
#        69., 69., 69., 69., 69., 68., 68., 68., 68., 67., 67., 67., 67.,
#        67., 67., 67., 67., 67., 67., 67., 67., 67., 68., 68., 68., 68.,
#        68., 67., 67., 67., 67., 67., 67., 67., 68., 67., 67., nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan])

# %%
# only finds continuous nan sequences interspersed within the data - channel 3 is missing 1.0 (100%) of its data
input_signal.map(lambda x: find_long_nan_sequences(x))
# Out:
# hr      0.0
# hbo     0.0
# eda     0.0
# hrv     1.0
# temp    0.0
# Name: 0, dtype: float64

# %%
# find max percent missing for each trial
for fraction_threshold in range(11):
    temp = signal_df.map(lambda x: find_long_nan_sequences(x) > fraction_threshold/10)
    print(f'# of signal channels above nan threshold %{fraction_threshold/10}: ', [f'{c}:{temp[c].sum()}' for c in ['hr', 'hbo', 'eda', 'hrv', 'temp']])
# Out:
# # of signal channels above nan threshold %0.0:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.1:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.2:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.3:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.4:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.5:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.6:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.7:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.8:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %0.9:  ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7']
# # of signal channels above nan threshold %1.0:  ['hr:0', 'hbo:0', 'eda:0', 'hrv:0', 'temp:0']

# %%
# for these channels, ['hr:15', 'hbo:15', 'eda:7', 'hrv:151', 'temp:7'] so many are above 90% nan values!

# %%
# trials are removed that are found to have more than 90% nan values in any one channel
all_nan = signal_df.map(lambda x: find_long_nan_sequences(x) > 0.9)

# %%
# 151 trials have a channel missing more than 90% values, not counting tailing nan values
rows_with_missing_channels = all_nan.apply(lambda x: x.any(), axis=1)
rows_with_missing_channels, rows_with_missing_channels.sum()
# Out:
# (0       True
#  1       True
#  2       True
#  3       True
#  4       True
#         ...
#  923    False
#  924    False
#  925    False
#  926    False
#  927    False
#  Length: 928, dtype: bool,
#  np.int64(151))

# %%
# remove all trials with any channel missing more than 90%
signal_df = signal_df[~rows_with_missing_channels]
signal_df
# Out:
#                                                     hr  \
# 96   [86.0, 86.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85....
# 97   [89.0, 90.0, 89.0, 83.0, 76.0, 75.0, 74.0, 75....
# 98   [81.0, 80.0, 79.0, 79.0, 80.0, 80.0, 80.0, 80....
# 99   [90.0, 90.0, 89.0, 89.0, 88.0, 88.0, 88.0, 89....
# 100  [85.0, 85.0, 85.0, 85.0, 83.0, 82.0, 80.0, 80....
# ..                                                 ...
# 923  [149.0, 149.0, 149.0, 149.0, 149.0, 149.0, 150...
# 924  [138.0, 138.0, 139.0, 140.0, 140.0, 140.0, 140...
# 925  [138.0, 138.0, 138.0, 138.0, 139.0, 139.0, 139...
# 926  [140.0, 140.0, 141.0, 141.0, 141.0, 142.0, 142...
# 927  [139.0, 139.0, 140.0, 140.0, 141.0, 142.0, 143...
#
#                                                    hbo  \
# 96   [-0.3046305720835594, -0.31955881048304857, -0...
# 97   [8.052234975262033, 8.033719458490888, 8.13857...
# 98   [11.730046881495785, 11.693972329257496, 11.85...
# 99   [-3.7118986439529715, -3.6020856713586022, -3....
# 100  [2.9662142523880535, 2.6790208296620466, 2.716...
# ..                                                 ...
# 923  [-23.10538728883509, -23.05403200438451, -23.1...
# 924  [3.058798375795244, 2.655746357782251, 2.55250...
# 925  [-2.7496252732924376, -2.6766007643420946, -2....
# 926  [17.369855603108817, 17.267840840287466, 17.67...
# 927  [-0.625898442808352, -0.6398860900049662, -0.3...
#
#                                                    eda  \
# 96   [2.36582778551346, 2.3711798555679184, 2.37761...
# 97   [1.4318178800804344, 1.4347531463715082, 1.438...
# 98   [2.93365803430117, 2.916177078764427, 2.905066...
# 99   [1.360926244516401, 1.368126748476356, 1.37547...
# 100  [1.2437807082337249, 1.24384202999343, 1.24382...
# ..                                                 ...
# 923  [6.123965544413717, 6.09872522717756, 6.066599...
# 924  [20.37602942760572, 20.297138745295264, 20.182...
# 925  [10.658320792222952, 10.677367210273614, 10.69...
# 926  [12.171594831168214, 12.151301662457728, 12.13...
# 927  [13.675999616916716, 13.81861341589344, 13.988...
#
#                                                    hrv  \
# 96   [728.0, 723.0, 696.0, 695.0, 698.0, 713.0, 716...
# 97   [649.0, 776.0, 964.0, 958.0, 938.0, 882.0, 809...
# 98   [820.0, 787.0, 743.0, 725.0, 729.0, 744.0, 775...
# 99   [677.0, 697.0, 679.0, 691.0, 696.0, 691.0, 691...
# 100  [692.0, 709.0, 707.0, 735.0, 761.0, 844.0, 868...
# ..                                                 ...
# 923  [391.0, 392.0, 391.0, 389.0, 390.0, 388.0, 389...
# 924  [425.0, 423.0, 421.0, 420.0, 421.0, 423.0, 420...
# 925  [415.0, 416.0, 417.0, 413.0, 414.0, 416.0, 416...
# 926  [419.0, 416.0, 417.0, 418.0, 419.0, 417.0, 416...
# 927  [406.0, 405.0, 403.0, 406.0, 404.0, 405.0, 403...
#
#                                                   temp
# 96   [34.34, 34.34, 34.34, 34.34, 34.34, 34.34, 34....
# 97   [34.15, 34.15, 34.15, 34.15, 34.15, 34.15, 34....
# 98   [34.41, 34.43, 34.43, 34.43, 34.43, 34.41, 34....
# 99   [33.41, 33.39, 33.39, 33.39, 33.39, 33.41, 33....
# 100  [34.37, 34.37, 34.37, 34.37, 34.37, 34.37, 34....
# ..                                                 ...
# 923  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 924  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 925  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 926  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 927  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
#
# [777 rows x 5 columns]

# %%
# arrays have exclusively tailing nan values or are completely missing data. Does each array have the same fraction of tailing nan values?
arr = []
for c in ['hr', 'hbo', 'eda', 'hrv', 'temp']:
    s = input_signal[c]
    r = np.sum(np.isnan(s)) / len(s)
    print(r)
    arr.append(r)

# each array seems to have the same tail-end fraction cut off by nan values. 
# This means the variance of the nan_count to array_length ratio should be close to 0. 
# Since the variance is the mean standard deviation, it is very sensitive to outliers
# Any values above a certain threshold suggest that an array with far more missing values is present. 
print('variance of nan to signal length ratio across channels', np.var(np.array(arr)))
# Out:
# 0.3155080213903743
# 0.31852423355943466
# 0.3181818181818182
# 1.0
# 0.3181818181818182
# variance of nan to signal length ratio across channels 0.07450856742213492

# %%
nan_variance = signal_df.apply(lambda y: np.var([y.map(lambda x: np.sum(np.isnan(x)) / len(x))]), axis=1)
# with all trials removed that have missing signal channels, the variance is very high cfor channels with an uneven amount of tailing nan values
print(nan_variance,'median accross all rows', nan_variance.median())
# Out:
# 96     0.001232
# 97     0.001839
# 98     0.002100
# 99     0.000942
# 100    0.001849
#          ...
# 923    0.017855
# 924    0.011198
# 925    0.007222
# 926    0.011874
# 927    0.013168
# Length: 777, dtype: float64 median accross all rows 0.0030050632295451035

# %%
# the median absolute deviation measures dispersion of values around the median. Taking the z-score, the convention is to flag Zmad > 3 as potential outliers
nan_var_med = nan_variance.median()
mad = np.median(np.abs(nan_variance - nan_var_med))
mad_z_scores = np.abs(nan_variance - nan_var_med) / (1.4826 * mad)
mad_z_scores
# Out:
# 96     0.459403
# 97     0.302170
# 98     0.234548
# 99     0.534518
# 100    0.299469
#          ...
# 923    3.846486
# 924    2.122214
# 925    1.092324
# 926    2.297422
# 927    2.632424
# Length: 777, dtype: float64

# %%
# boolean index of high z_scores - potential outliers
outliers = mad_z_scores > 3
outliers, outliers.sum()
# Out:
# (96     False
#  97     False
#  98     False
#  99     False
#  100    False
#         ...
#  923     True
#  924    False
#  925    False
#  926    False
#  927    False
#  Length: 777, dtype: bool,
#  np.int64(47))

# %%
# all trials flagged as outliers: for the shorter sequence length channels, these are clearly visible
signal_df[outliers]
# Out:
#                                                     hr  \
# 146  [102.0, 103.0, 103.0, 103.0, 104.0, 104.0, 105...
# 147  [100.0, 101.0, 102.0, 103.0, 104.0, 104.0, 105...
# 150  [103.0, 102.0, 102.0, 102.0, 103.0, 104.0, 105...
# 151  [107.0, 106.0, 105.0, 105.0, 104.0, 104.0, 105...
# 292  [75.0, 76.0, 76.0, 77.0, 79.0, 80.0, 80.0, 81....
# 293  [78.0, 79.0, 80.0, 81.0, 80.0, 79.0, 78.0, 78....
# 320  [96.0, nan, nan, nan, nan, nan, nan, nan, nan,...
# 321  [96.0, nan, nan, nan, nan, nan, nan, nan, nan,...
# 322  [96.0, nan, nan, nan, nan, nan, nan, nan, nan,...
# 323  [96.0, nan, nan, nan, nan, nan, nan, nan, nan,...
# 324  [96.0, 95.0, 95.0, 95.0, 95.0, 94.0, 93.0, 92....
# 344  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 345  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 346  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 347  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 348  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 349  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 350  [132.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 442  [125.0, 125.0, 125.0, 126.0, 126.0, 126.0, 127...
# 446  [132.0, 132.0, 133.0, 133.0, 133.0, 133.0, 133...
# 447  [124.0, 124.0, 125.0, 125.0, 125.0, 126.0, 127...
# 450  [72.0, 71.0, 70.0, 70.0, 71.0, 71.0, 70.0, 70....
# 452  [72.0, 72.0, 72.0, 72.0, 70.0, 70.0, 70.0, 70....
# 453  [64.0, 64.0, 64.0, 65.0, 64.0, 63.0, 62.0, 62....
# 454  [71.0, 72.0, 72.0, 73.0, 74.0, 74.0, 75.0, 75....
# 545  [74.0, 73.0, 73.0, 72.0, 71.0, 71.0, 71.0, 73....
# 547  [72.0, 72.0, 74.0, 75.0, 80.0, 82.0, 83.0, 85....
# 549  [73.0, 74.0, 75.0, 75.0, 74.0, 73.0, 72.0, 72....
# 550  [72.0, 73.0, 74.0, 74.0, 73.0, 73.0, 72.0, 72....
# 576  [83.0, 83.0, 83.0, 83.0, 83.0, 82.0, 81.0, 82....
# 677  [63.0, 63.0, 63.0, 62.0, 62.0, 61.0, 61.0, 61....
# 678  [63.0, 62.0, 61.0, 60.0, 59.0, 58.0, 58.0, 58....
# 679  [62.0, 62.0, 61.0, 61.0, 61.0, 61.0, 60.0, 60....
# 825  [149.0, 149.0, 150.0, 151.0, 151.0, 152.0, 153...
# 826  [153.0, 153.0, 153.0, 153.0, 154.0, 155.0, 156...
# 827  [158.0, 158.0, 157.0, 157.0, 158.0, 158.0, 158...
# 831  [153.0, 154.0, 155.0, 155.0, 156.0, 156.0, 157...
# 888  [123.0, 123.0, 123.0, 124.0, 124.0, 125.0, 126...
# 889  [127.0, 128.0, 129.0, 129.0, 130.0, 130.0, 130...
# 890  [115.0, 117.0, 119.0, 120.0, 121.0, 122.0, 123...
# 891  [118.0, 120.0, 121.0, 123.0, 124.0, 127.0, 127...
# 892  [135.0, 134.0, 134.0, 134.0, 134.0, 134.0, 134...
# 893  [127.0, 127.0, 127.0, 128.0, 128.0, 128.0, 128...
# 894  [134.0, 134.0, 135.0, 135.0, 134.0, 134.0, 134...
# 895  [129.0, 128.0, 127.0, 127.0, 126.0, 126.0, 127...
# 922  [142.0, 142.0, 142.0, 142.0, 142.0, 143.0, 143...
# 923  [149.0, 149.0, 149.0, 149.0, 149.0, 149.0, 150...
#
#                                                    hbo  \
# 146  [-8.823993915085032, -8.840882687392488, -8.77...
# 147  [-7.828278666123876, -7.938407956434872, -7.95...
# 150  [-7.787689556400292, -7.747496611991344, -7.65...
# 151  [-2.110626571324452, -1.9622803175438148, -1.9...
# 292  [-4.649254304993229, -4.61831301089607, -4.615...
# 293  [3.2149497072749393, 3.276974031340498, 3.2076...
# 320  [-1.261301074625934, -1.223298045035024, -1.21...
# 321  [-4.83593773867081, -4.830249535933329, -4.790...
# 322  [1.4378971712766797, 1.4225714894052117, 1.441...
# 323  [1.251462946587023, 1.2434395620048506, 1.2038...
# 324  [7.353095149226869, 7.3277900576664114, 7.3557...
# 344  [0.4028425320882427, 0.610245681592885, 0.6197...
# 345  [-3.567226112010534, -3.192398848458581, -2.82...
# 346  [3.1765057718120717, 3.296012626504648, 3.3957...
# 347  [-13.676420092616464, -13.844476589967007, -13...
# 348  [5.358722050629216, 5.440843031125377, 5.44103...
# 349  [4.790748778979138, 7.51599778787031, 6.322219...
# 350  [8.57601959629532, 8.540933941262205, 8.466720...
# 442  [-29.143960724720856, -29.98984035074468, -29....
# 446  [157.9421696907589, 154.1083597248019, 157.869...
# 447  [72.1632660613074, 76.03000210391676, 77.31197...
# 450  [24.57619785209572, 24.413370514320217, 24.437...
# 452  [-13.746871442961847, -13.500700121384552, -13...
# 453  [-6.492308634413458, -6.580486836197195, -6.38...
# 454  [-13.190814435038886, -13.454749776315017, -13...
# 545  [2.3223683801722483, 2.314123846263735, 2.2685...
# 547  [-10.607879129706243, -10.587343700517426, -10...
# 549  [-4.977702412573374, -4.984034969756034, -4.91...
# 550  [-9.832735686195313, -9.804703879307965, -9.80...
# 576  [-4.006238572536664, -3.9915633471450285, -4.0...
# 677  [-3.1472936064412096, -3.2616682806303237, -3....
# 678  [7.754298659814487, 7.80007909637262, 7.835193...
# 679  [0.5360734689170104, 0.6509891260643056, 0.629...
# 825  [-62.33331932778339, -62.27270031218683, -62.5...
# 826  [-78.96342619490795, -78.98804531920158, -79.2...
# 827  [-42.511615822058566, -42.68234799309504, -42....
# 831  [-19.128697136693944, -19.007094592371377, -19...
# 888  [-11.73857113481767, -11.725634212460712, -11....
# 889  [-4.813158389843797, -4.750137448812535, -4.96...
# 890  [-3.1238522789622345, -3.19554449979943, -3.19...
# 891  [-10.252958806312506, -10.20779380058398, -9.8...
# 892  [-3.011115470664052, -2.880828797056548, -2.71...
# 893  [-6.874311534010805, -6.579633899841978, -6.64...
# 894  [-1.8727941953235585, -2.025996504911117, -1.7...
# 895  [-6.43405027552362, -6.291980789515729, -6.464...
# 922  [-14.620701306454249, -14.692356102389146, -14...
# 923  [-23.10538728883509, -23.05403200438451, -23.1...
#
#                                                    eda  \
# 146  [0.1041230192439944, 0.10358191494526042, 0.10...
# 147  [0.13142537833554185, 0.13358221389344, 0.1363...
# 150  [0.21886583097416304, 0.22113014904364703, 0.2...
# 151  [0.22368499399303163, 0.22392059952748186, 0.2...
# 292  [2.394393902079656, 2.395028785246666, 2.39595...
# 293  [2.5772797625690678, 2.575284154546029, 2.5730...
# 320  [4.589267828668605, 4.577069339759905, 4.56793...
# 321  [3.952255300848163, 3.9830227102247435, 4.0130...
# 322  [3.9115963478904026, 3.9186041870467747, 3.929...
# 323  [4.455995135060351, 4.454483908740345, 4.45388...
# 324  [4.2138499379201235, 4.193280961581244, 4.1758...
# 344  [6.1091184390433755, 6.063391301572858, 6.0205...
# 345  [3.1940336307261172, 3.217757573038781, 3.2461...
# 346  [7.574924075486771, 7.616898590511713, 7.65122...
# 347  [0.4905742852663493, 0.4917991266297113, 0.492...
# 348  [16.247618510265816, 16.1677106865566, 16.0841...
# 349  [14.217934656567584, 14.231778385997513, 14.24...
# 350  [17.269915414464638, 17.22576496780617, 17.173...
# 442  [32.939215533889254, 33.028255957843285, 33.14...
# 446  [26.137253735373704, 26.03982255215487, 26.037...
# 447  [33.67737452912613, 33.56112097430968, 33.4731...
# 450  [3.431638818315014, 3.4509702376576996, 3.4628...
# 452  [2.0500259749267298, 2.049461385900627, 2.0454...
# 453  [1.586324809452875, 1.5901674701001727, 1.5892...
# 454  [1.5434630776925429, 1.5475766173233405, 1.549...
# 545  [0.137513898154456, 0.1388877740399536, 0.1399...
# 547  [0.17017600023928492, 0.17018571498969154, 0.1...
# 549  [0.17570268269625333, 0.1739852692439541, 0.17...
# 550  [0.15492790117478955, 0.15556500186572225, 0.1...
# 576  [0.4130513770196641, 0.4568328975906351, 0.495...
# 677  [1.175903321296725, 1.1752581919639862, 1.1728...
# 678  [1.4533293473797086, 1.4430825556531297, 1.429...
# 679  [1.9200658737889367, 1.907880674740612, 1.8912...
# 825  [2.9030081397466456, 2.9095006119467004, 2.912...
# 826  [35.72017678699504, 35.71771567162231, 35.7161...
# 827  [8.177574086371026, 8.181237519657572, 8.18340...
# 831  [56.205416267117755, 56.02439694738369, 55.863...
# 888  [4.867509546768703, 4.893275647270891, 4.93214...
# 889  [6.720452683514631, 6.731251365881089, 6.74330...
# 890  [8.303982087461256, 8.323979553446614, 8.34223...
# 891  [5.736027792854182, 5.760134633448856, 5.78690...
# 892  [5.981676987820005, 5.979306624379049, 5.97912...
# 893  [4.8524906167622275, 4.8624202327329735, 4.864...
# 894  [8.241364452948607, 8.206804025619881, 8.17871...
# 895  [6.395182235965052, 6.4149238557210255, 6.4387...
# 922  [10.072219500065062, 10.036255082593284, 9.996...
# 923  [6.123965544413717, 6.09872522717756, 6.066599...
#
#                                                    hrv  \
# 146  [589.0, 581.0, 577.0, 584.0, 584.0, 577.0, 573...
# 147  [586.0, 582.0, 587.0, 584.0, 576.0, 564.0, 561...
# 150  [589.0, 584.0, 584.0, 593.0, 587.0, 583.0, 587...
# 151  [563.0, 560.0, 577.0, 578.0, 576.0, 570.0, 591...
# 292  [814.0, 766.0, 805.0, 727.0, 713.0, 688.0, 671...
# 293  [718.0, 678.0, 695.0, 721.0, 836.0, 832.0, 846...
# 320  [655.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 321  [655.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 322  [655.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 323  [655.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 324  [655.0, 651.0, 624.0, 611.0, 626.0, 646.0, 646...
# 344  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 345  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 346  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 347  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 348  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 349  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 350  [448.0, nan, nan, nan, nan, nan, nan, nan, nan...
# 442  [479.0, 480.0, 483.0, 476.0, 477.0, 478.0, 479...
# 446  [456.0, 451.0, 451.0, 447.0, 448.0, 451.0, 453...
# 447  [484.0, 482.0, 480.0, 478.0, 481.0, 481.0, 480...
# 450  [968.0, 943.0, 853.0, 807.0, 802.0, 856.0, 947...
# 452  [793.0, 849.0, 920.0, 942.0, 915.0, 887.0, 882...
# 453  [868.0, 879.0, 971.0, 1091.0, 1069.0, 1032.0, ...
# 454  [790.0, 803.0, 785.0, 755.0, 751.0, 767.0, 770...
# 545  [921.0, 866.0, 896.0, 902.0, 919.0, 863.0, 798...
# 547  [876.0, 774.0, 752.0, 700.0, 712.0, 658.0, 634...
# 549  [731.0, 720.0, 789.0, 862.0, 1025.0, 950.0, 83...
# 550  [765.0, 742.0, 827.0, 831.0, 868.0, 866.0, 866...
# 576  [712.0, 709.0, 741.0, 781.0, 755.0, 781.0, 759...
# 677  [1011.0, 1040.0, 1092.0, 1066.0, 1025.0, 999.0...
# 678  [1193.0, 1175.0, 1161.0, 1034.0, 1066.0, 1000....
# 679  [1033.0, 1010.0, 1020.0, 1021.0, 1026.0, 982.0...
# 825  [401.0, 405.0, 403.0, 401.0, 399.0, 401.0, 400...
# 826  [393.0, 394.0, 393.0, 395.0, 394.0, 396.0, 395...
# 827  [380.0, 379.0, 379.0, 381.0, 381.0, 380.0, 381...
# 831  [393.0, 390.0, 386.0, 387.0, 387.0, 386.0, 385...
# 888  [484.0, 491.0, 489.0, 487.0, 487.0, 487.0, 481...
# 889  [465.0, 462.0, 463.0, 462.0, 460.0, 462.0, 463...
# 890  [499.0, 501.0, 503.0, 493.0, 488.0, 495.0, 489...
# 891  [501.0, 501.0, 495.0, 485.0, 482.0, 483.0, 476...
# 892  [446.0, 448.0, 452.0, 448.0, 451.0, 450.0, 447...
# 893  [474.0, 468.0, 472.0, 473.0, 466.0, 470.0, 471...
# 894  [441.0, 445.0, 447.0, 440.0, 444.0, 446.0, 441...
# 895  [469.0, 467.0, 478.0, 472.0, 476.0, 478.0, 481...
# 922  [405.0, 403.0, 404.0, 402.0, 405.0, 401.0, 401...
# 923  [391.0, 392.0, 391.0, 389.0, 390.0, 388.0, 389...
#
#                                                   temp
# 146  [30.49, 30.49, 30.49, 30.49, 30.49, 30.47, 30....
# 147  [30.33, 30.33, 30.33, 30.31, 30.31, 30.31, 30....
# 150  [32.63, 32.63, 32.63, 32.66, 32.66, 32.66, 32....
# 151  [33.33, 33.33, 33.33, 33.33, 33.33, 33.33, 33....
# 292  [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 32....
# 293  [32.41, 32.41, 32.41, 32.41, 32.41, 32.41, 32....
# 320  [35.71, 35.71, 35.71, 35.68, 35.68, 35.68, 35....
# 321  [35.47, 35.47, 35.5, 35.5, 35.5, 35.5, 35.5, 3...
# 322  [35.5, 35.5, 35.5, 35.55, 35.55, 35.55, 35.55,...
# 323  [35.53, 35.53, 35.53, 35.49, 35.49, 35.49, 35....
# 324  [35.29, 35.31, 35.31, 35.31, 35.31, 35.29, 35....
# 344  [32.09, 32.09, 32.09, 32.11, 32.11, 32.11, 32....
# 345  [31.93, 31.93, 31.93, 31.95, 31.95, 31.95, 31....
# 346  [32.66, 32.65, 32.65, 32.65, 32.65, 32.65, 32....
# 347  [32.07, 32.07, 32.05, 32.05, 32.05, 32.05, 32....
# 348  [33.65, 33.65, 33.66, 33.66, 33.66, 33.66, 33....
# 349  [33.21, 33.23, 33.23, 33.23, 33.23, 33.21, 33....
# 350  [33.55, 33.55, 33.59, 33.59, 33.59, 33.59, 33....
# 442  [33.5, 33.5, 33.5, 33.5, 33.5, 33.5, 33.5, 33....
# 446  [34.49, 34.49, 34.49, 34.47, 34.47, 34.47, 34....
# 447  [34.45, 34.43, 34.43, 34.43, 34.43, 34.45, 34....
# 450  [33.09, 33.11, 33.11, 33.11, 33.11, 33.11, 33....
# 452  [33.45, 33.45, 33.45, 33.45, 33.45, 33.45, 33....
# 453  [33.33, 33.33, 33.33, 33.33, 33.33, 33.33, 33....
# 454  [33.34, 33.34, 33.37, 33.37, 33.37, 33.37, 33....
# 545  [34.23, 34.23, 34.23, 34.23, 34.23, 34.23, 34....
# 547  [34.29, 34.29, 34.31, 34.31, 34.31, 34.31, 34....
# 549  [34.57, 34.59, 34.59, 34.59, 34.59, 34.59, 34....
# 550  [34.41, 34.41, 34.43, 34.43, 34.43, 34.43, 34....
# 576  [29.19, 29.19, 29.19, 29.19, 29.17, 29.17, 29....
# 677  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 678  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 679  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 825  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 826  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 827  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 831  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 888  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 889  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 890  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 891  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 892  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 893  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 894  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 895  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 922  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 923  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...

# %%
# remove trials with outlier z-score higher than 3
signal_df = signal_df[~outliers]

# %%
signal_df
# Out:
#                                                     hr  \
# 96   [86.0, 86.0, 85.0, 85.0, 85.0, 85.0, 85.0, 85....
# 97   [89.0, 90.0, 89.0, 83.0, 76.0, 75.0, 74.0, 75....
# 98   [81.0, 80.0, 79.0, 79.0, 80.0, 80.0, 80.0, 80....
# 99   [90.0, 90.0, 89.0, 89.0, 88.0, 88.0, 88.0, 89....
# 100  [85.0, 85.0, 85.0, 85.0, 83.0, 82.0, 80.0, 80....
# ..                                                 ...
# 921  [146.0, 146.0, 146.0, 146.0, 147.0, 147.0, 148...
# 924  [138.0, 138.0, 139.0, 140.0, 140.0, 140.0, 140...
# 925  [138.0, 138.0, 138.0, 138.0, 139.0, 139.0, 139...
# 926  [140.0, 140.0, 141.0, 141.0, 141.0, 142.0, 142...
# 927  [139.0, 139.0, 140.0, 140.0, 141.0, 142.0, 143...
#
#                                                    hbo  \
# 96   [-0.3046305720835594, -0.31955881048304857, -0...
# 97   [8.052234975262033, 8.033719458490888, 8.13857...
# 98   [11.730046881495785, 11.693972329257496, 11.85...
# 99   [-3.7118986439529715, -3.6020856713586022, -3....
# 100  [2.9662142523880535, 2.6790208296620466, 2.716...
# ..                                                 ...
# 921  [-41.49453834236974, -41.42930016955021, -41.4...
# 924  [3.058798375795244, 2.655746357782251, 2.55250...
# 925  [-2.7496252732924376, -2.6766007643420946, -2....
# 926  [17.369855603108817, 17.267840840287466, 17.67...
# 927  [-0.625898442808352, -0.6398860900049662, -0.3...
#
#                                                    eda  \
# 96   [2.36582778551346, 2.3711798555679184, 2.37761...
# 97   [1.4318178800804344, 1.4347531463715082, 1.438...
# 98   [2.93365803430117, 2.916177078764427, 2.905066...
# 99   [1.360926244516401, 1.368126748476356, 1.37547...
# 100  [1.2437807082337249, 1.24384202999343, 1.24382...
# ..                                                 ...
# 921  [1.7414557833087962, 1.727774149878133, 1.7175...
# 924  [20.37602942760572, 20.297138745295264, 20.182...
# 925  [10.658320792222952, 10.677367210273614, 10.69...
# 926  [12.171594831168214, 12.151301662457728, 12.13...
# 927  [13.675999616916716, 13.81861341589344, 13.988...
#
#                                                    hrv  \
# 96   [728.0, 723.0, 696.0, 695.0, 698.0, 713.0, 716...
# 97   [649.0, 776.0, 964.0, 958.0, 938.0, 882.0, 809...
# 98   [820.0, 787.0, 743.0, 725.0, 729.0, 744.0, 775...
# 99   [677.0, 697.0, 679.0, 691.0, 696.0, 691.0, 691...
# 100  [692.0, 709.0, 707.0, 735.0, 761.0, 844.0, 868...
# ..                                                 ...
# 921  [409.0, 408.0, 406.0, 407.0, 408.0, 405.0, 406...
# 924  [425.0, 423.0, 421.0, 420.0, 421.0, 423.0, 420...
# 925  [415.0, 416.0, 417.0, 413.0, 414.0, 416.0, 416...
# 926  [419.0, 416.0, 417.0, 418.0, 419.0, 417.0, 416...
# 927  [406.0, 405.0, 403.0, 406.0, 404.0, 405.0, 403...
#
#                                                   temp
# 96   [34.34, 34.34, 34.34, 34.34, 34.34, 34.34, 34....
# 97   [34.15, 34.15, 34.15, 34.15, 34.15, 34.15, 34....
# 98   [34.41, 34.43, 34.43, 34.43, 34.43, 34.41, 34....
# 99   [33.41, 33.39, 33.39, 33.39, 33.39, 33.41, 33....
# 100  [34.37, 34.37, 34.37, 34.37, 34.37, 34.37, 34....
# ..                                                 ...
# 921  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 924  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 925  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 926  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
# 927  [382.21, 382.21, 382.21, 382.21, 382.21, 382.2...
#
# [730 rows x 5 columns]

# %%
nan_to_length_ratio = signal_df.map(lambda x: np.sum(np.isnan(x)) / len(x)).apply(lambda x: x.max(), axis=1)
nan_to_length_ratio
# Out:
# 96     0.482143
# 97     0.500000
# 98     0.500000
# 99     0.467262
# 100    0.502976
#          ...
# 921    0.350785
# 924    0.350785
# 925    0.331080
# 926    0.334054
# 927    0.335889
# Length: 730, dtype: float64

# %%
percent_nan = np.array([nan_to_length_ratio.values for _ in range(5)]).T
percent_nan
# Out:
# array([[0.48214286, 0.48214286, 0.48214286, 0.48214286, 0.48214286],
#        [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ],
#        ...,
#        [0.33107958, 0.33107958, 0.33107958, 0.33107958, 0.33107958],
#        [0.33405411, 0.33405411, 0.33405411, 0.33405411, 0.33405411],
#        [0.33588946, 0.33588946, 0.33588946, 0.33588946, 0.33588946]])

# %%
percent_nan.shape
# Out:
# (730, 5)

# %%
arr_length = signal_df.map(lambda x: len(x))
arr_length
# Out:
#       hr     hbo  eda  hrv  temp
# 96   203  101041  809  336   809
# 97   203  101041  809  336   809
# 98   203  101041  809  336   809
# 99   203  101041  809  336   809
# 100  203  101041  809  336   809
# ..   ...     ...  ...  ...   ...
# 921  191   94805  759  332   759
# 924  191   94805  759  332   759
# 925  191   94805  759  332   759
# 926  191   94805  759  332   759
# 927  191   94805  759  332   759
#
# [730 rows x 5 columns]

# %%
arr_length.values.shape
# Out:
# (730, 5)

# %%
indexes = percent_nan * arr_length.values
indexes, indexes.shape
# Out:
# (array([[   97.875     , 48716.19642857,   390.05357143,   162.        ,
#            390.05357143],
#         [  101.5       , 50520.5       ,   404.5       ,   168.        ,
#            404.5       ],
#         [  101.5       , 50520.5       ,   404.5       ,   168.        ,
#            404.5       ],
#         ...,
#         [   63.23620062, 31388.        ,   251.28940457,   109.91842202,
#            251.28940457],
#         [   63.80433521, 31670.        ,   253.5470703 ,   110.90596488,
#            253.5470703 ],
#         [   64.15488635, 31844.        ,   254.9400981 ,   111.51529983,
#            254.9400981 ]]),
#  (730, 5))

# %%
signal_np = signal_df.values
signal_np.shape
# Out:
# (730, 5)

# %%
# Extract elements using loops
signal_np_truncated = np.empty((730, 5), dtype=object)

for i in range(730):
    for j in range(5):
        idx = int(indexes[i, j]) 
        seq = signal_np[i, j]  
        if idx < len(seq):  
            signal_np_truncated[i, j] = seq[:-idx]
        else:
            raise ValueError(f'There are {idx} nan values in a sequence of lenght {len(seq)}')

# %%
signal_np_truncated.shape
# Out:
# (730, 5)

# %%
input_signal.map(lambda x: len(x) if type(x) == np.ndarray else x)
# Out:
# hr        187
# hbo     93321
# eda       748
# hrv         5
# temp      748
# Name: 0, dtype: int64

# %%
whole_df[['hr', 'hbo', 'eda', 'hrv', 'temp']].apply(lambda y: y.map(lambda x: len(x)).min())
# Out:
# hr        185
# hbo     91811
# eda       735
# hrv         5
# temp      735
# dtype: int64

# %%
min_timeframe = whole_df['eda'].map(lambda x: len(x)).min()
min_timeframe
# Out:
# np.int64(735)

# %%
def stretch_arr(t, target_len):
    
    orig_len = len(t)
    orig_idx = np.linspace(0, target_len - 1, orig_len)
    new_idx = np.arange(target_len) 

    # linear interpolation
    interpolated = np.interp(new_idx, orig_idx, t)

    return torch.tensor(interpolated, dtype=torch.float32)

# %%
t1 = np.array([1, 2, 3, np.nan, 5, np.nan, 7, 8, 9, 10, np.nan, 8, 7, 6, 5, 4, 3, 2, 1])
t2 = np.array([5, 6])
t3 = np.array([7, 8, np.nan, 10, 11])

tensors = [t1, t2, t3]

# length to which other tensors are downsampled
resample = len(t1)

# stretch to resample length and stack, now they fit
t_stretched = torch.stack([stretch_arr(t, resample) for t in tensors])

t_stretched
# Out:
# tensor([[ 1.0000,  2.0000,  3.0000,     nan,  5.0000,     nan,  7.0000,  8.0000,
#           9.0000, 10.0000,     nan,  8.0000,  7.0000,  6.0000,  5.0000,  4.0000,
#           3.0000,  2.0000,  1.0000],
#         [ 5.0000,  5.0556,  5.1111,  5.1667,  5.2222,  5.2778,  5.3333,  5.3889,
#           5.4444,  5.5000,  5.5556,  5.6111,  5.6667,  5.7222,  5.7778,  5.8333,
#           5.8889,  5.9444,  6.0000],
#         [ 7.0000,  7.2222,  7.4444,  7.6667,  7.8889,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan, 10.1111, 10.3333,
#          10.5556, 10.7778, 11.0000]])

# %%
def fill_nan_running_mean(arr):
    mask = np.isnan(arr)
    if np.all(mask): 
        return np.zeros_like(arr)
    
    # cumulative sum of array
    cumsum = np.nancumsum(arr)
    # cumulative count of valid elements
    count = np.cumsum(~mask)
    running_mean = np.divide(cumsum, count, where=(count != 0))

    arr[mask] = running_mean[mask]
    return arr

# %%
t1
# Out:
# array([ 1.,  2.,  3., nan,  5., nan,  7.,  8.,  9., 10., nan,  8.,  7.,
#         6.,  5.,  4.,  3.,  2.,  1.])

# %%
features = whole_df[['hr', 'hbo', 'eda', 'hrv', 'temp']].values
labels = whole_df[['subj', 'label']].values

features.shape, labels.shape
# Out:
# ((928, 5), (928, 2))

# %%
whole_df[['subj', 'label']].nunique()
# Out:
# subj     29
# label     4
# dtype: int64

# %%
c = {'hr':0, 'hbo':1, 'eda':2, 'hrv':3, 'temp':4}
list(c.keys())
# Out:
# ['hr', 'hbo', 'eda', 'hrv', 'temp']

# %%
type(whole_df.loc[0, 'hr'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(whole_df.loc[0, 'hr'])
#
# NameError: name 'whole_df' is not defined
